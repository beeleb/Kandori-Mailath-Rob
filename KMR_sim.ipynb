# %%
# %matplotlib inline

# %%
from KMR_class import KMR, set_pay

# %%
payoff = [[[4,4],[0,3]],[[3,0],[2,2]]]
set_pay(payoff)
# Out:
# OK. one_payoff is
# [[4 0]
#  [3 2]]

# %%
N = 10
epsilon = 0.05
mode = 'simultaneous'
x0_p = 0
T = 10**5

# %%
kmr = KMR(N, x0_p, epsilon, mode)

# %%
kmr.plot(T)

# %%
kmr.hist(T)

# %%
kmr.equilibrium()
